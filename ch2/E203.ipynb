# %% [markdown]
# # Rescaling data

# %% [markdown]
# This exercise rescales the data from E202. In order to prevent having to type it all again we are just going to use the `%run` command.

# %%
# %run E202.ipynb
# Out:
# (19735, 28)
# <bound method NDFrame.head of        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...         T9     RH_9  \
# ...

# %%
#since we have access to the outliers variable we now this worked.
outliers
# Out:
# {'Appliances': '0.027',
#  'lights': '0.033',
#  'T1': '0.000',
#  'RH_1': '0.005',
#  'T2': '0.010',
#  'RH_2': '0.002',
#  'T3': '0.003',
#  'RH_3': '0.001',
#  'T4': '0.000',
#  'RH_4': '0.000',
#  'T5': '0.001',
#  'RH_5': '0.029',
#  'T6': '0.005',
#  'RH_6': '0.000',
#  'T7': '0.000',
#  'RH_7': '0.001',
#  'T8': '0.000',
#  'RH_8': '0.000',
#  'T9': '0.000',
#  'RH_9': '0.000',
#  'T_out': '0.005',
#  'Press_mm_hg': '0.000',
#  'RH_out': '0.000',
#  'Windspeed': '0.005',
#  'Visibility': '0.000',
#  'Tdewpoint': '0.000',
#  'rv1': '0.000',
#  'rv2': '0.000'}

# %%
# we are going to seperate the features from the target, using x and y, where x are the input_features and y is the target
x = data.iloc[:,1:] #everything at and after the first index
y = data.iloc[:, 0]

# %% [markdown]
# Rescale the features data by using `normalization` methodology. Display the head to verify result

# %%
x = (x-x.min()) / (x.max() - x.min())
x.head()
# Out:
#      lights       T1      RH_1        T2      RH_2        T3      RH_3  \
# 0  0.428571  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066
# 1  0.428571  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871
# 2  0.428571  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569
# 3  0.571429  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685
# 4  0.571429  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685
#
#          T4      RH_4        T5  ...        T9      RH_9     T_out  \
# 0  0.351351  0.764262  0.175506  ...  0.223032  0.677290  0.372990
# 1  0.351351  0.782437  0.175506  ...  0.226500  0.678532  0.369239
# 2  0.344745  0.778062  0.175506  ...  0.219563  0.676049  0.365488
# 3  0.341441  0.770949  0.175506  ...  0.219563  0.671909  0.361736
# 4  0.341441  0.762697  0.178691  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %% [markdown]
# And there you have it! More information on data normalization can be found [here](https://developers.google.com/machine-learning/data-prep/transform/normalization).
